# %% [markdown]
# # 00 — Scope & Plan

# %% [markdown]
# This notebook captures the problem framing and scoping details, constraints, risks, and the initial plan for data, features, modelling, and evaluation.

# %% [markdown]
# ## Problem Statement
# As in README.

# %% [markdown]
# ## Risks & Mitigations
# - Leakage, Overfitting, Regime shifts, Data quality

# %% [markdown]
# ## Initial Check: yfinance availability

# %%
import yfinance as yf, pandas as pd
print("yfinance version:", yf.__version__)
ticker = "AAPL"
df = yf.download(ticker, period="1y", interval="1d", progress=False).reset_index()
df.head()
