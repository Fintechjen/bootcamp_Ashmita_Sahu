# %% [markdown]
# # 00 — Environment & Config Check

# %% [markdown]
# Verifies `.env` loading and NumPy import.

# %%
from dotenv import load_dotenv
import os
import numpy as np

load_dotenv()
print("API_KEY present:", bool(os.getenv("API_KEY")))

a = np.array([1, 2, 3])
print("Array * 2 =>", a * 2)
